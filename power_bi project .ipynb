# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # load data and skip first 3 rows

# %%
df = pd.read_csv('wb_db_1.csv',skiprows=3)

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                 Indicator Name        Indicator Code  1960  \
# 0    Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN
# 1    Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN
# 2    Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN
# 3    Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            11 non-null     float64
#  15  1971            14 non-null     float64
#  16  1972            16 non-null     float64
# ...

# %% [markdown]
# # drop all NA columns

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 57 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1970            11 non-null     float64
#  5   1971            14 non-null     float64
#  6   1972            16 non-null     float64
#  7   1973            16 non-null     float64
#  8   1974            28 non-null     float64
#  9   1975            52 non-null     float64
#  10  1976            66 non-null     float64
#  11  1977            95 non-null     float64
#  12  1978            99 non-null     float64
#  13  1979            109 non-null    float64
#  14  1980            113 non-null    float64
#  15  1981            117 non-null    float64
#  16  1982            127 non-null    float64
# ...

# %%
df.describe(include='all')
# Out:
#        Country Name Country Code                             Indicator Name  \
# count           266          266                                        266
# unique          266          266                                          1
# top        Viet Nam          ALB  Personal remittances, received (% of GDP)
# freq              1            1                                        266
# mean            NaN          NaN                                        NaN
# std             NaN          NaN                                        NaN
# min             NaN          NaN                                        NaN
# 25%             NaN          NaN                                        NaN
# 50%             NaN          NaN                                        NaN
# 75%             NaN          NaN                                        NaN
# max             NaN          NaN                                        NaN
#
# ...

# %%
df_country = pd.read_csv('Metadata_Country.csv')

# %%
df_country
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_indicator = pd.read_csv('Metadata_Indicator.csv')

# %%
df_indicator
# Out:
#          INDICATOR_CODE                             INDICATOR_NAME  \
# 0  BX.TRF.PWKR.DT.GD.ZS  Personal remittances, received (% of GDP)
#
#                                          SOURCE_NOTE  \
# 0  Personal remittances comprise personal transfe...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  World Bank staff estimates based on IMF balanc...         NaN

# %% [markdown]
# # combine primary data with Metadata_Country

# %%
df_combined = pd.merge(df,df_country,how='left',on='Country Code')

# %%
df_combined.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                               Indicator Name        Indicator Code      1970  \
# 0  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS       NaN
# 1  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS  0.099291
# 2  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS       NaN
# 3  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS       NaN
# 4  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS       NaN
#
#        1971      1972      1973      1974      1975  ...      2018      2019  \
# 0       NaN       NaN       NaN       NaN       NaN  ...  1.126930  1.009012
# 1  0.089872  0.115434  0.079443  0.104931  0.451054  ...  1.347993  1.436747
# ...
